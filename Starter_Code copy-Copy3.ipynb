# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=['EIN', 'NAME'], inplace=True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = application_type_counts[application_type_counts < 500].index.tolist()


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts_greaterthan_1 = classification_counts[classification_counts > 1]
classification_counts_greaterthan_1
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# use the variable name `classifications_to_replace`
classifications_to_replace = classification_counts_greaterthan_1[classification_counts< 100].index.tolist()


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/neuralpython/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/envs/neuralpython/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/neuralpython/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CLASSIFICATION'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 9
#       7 # Replace in dataframe
#       8 for cls in classifications_to_replace:
# ----> 9     application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
#      11 # Check to make sure binning was successful
#      12 application_df['CLASSIFICATION'].value_counts()
#
# File ~/anaconda3/envs/neuralpython/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/envs/neuralpython/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'CLASSIFICATION'

# %%
# Convert categorical data to numeric with `pd.get_dummies`
# Generate the dummies for each categorical column
application_df = pd.get_dummies(application_df, columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'])
application_df.head()

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(['IS_SUCCESSFUL'],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# /var/folders/kh/xdg24th513g9kjvzg1lqylsc0000gn/T/ipykernel_77571/2823290356.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = application_df.drop(['IS_SUCCESSFUL'],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 20
hidden_nodes_layer4 = 10
hidden_nodes_layer5 = 10


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))

# Fifth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Metal device set to: Apple M2
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                6080
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 20)                620
#
#  dense_3 (Dense)             (None, 10)                210
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 9,461
# Trainable params: 9,461
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=200)
# Out:
# Epoch 1/200
# 2023-05-15 15:31:28.487478: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 804/804 [==============================] - 6s 5ms/step - loss: 0.5748 - accuracy: 0.7187
# Epoch 2/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5532 - accuracy: 0.7284
# Epoch 3/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5506 - accuracy: 0.7285
# Epoch 4/200
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5487 - accuracy: 0.7312
# Epoch 5/200
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5470 - accuracy: 0.7318
# Epoch 6/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5453 - accuracy: 0.7327
# Epoch 7/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5452 - accuracy: 0.7323
# Epoch 8/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5439 - accuracy: 0.7343
# Epoch 9/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5441 - accuracy: 0.7329
# Epoch 10/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5430 - accuracy: 0.7342
# Epoch 11/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5426 - accuracy: 0.7335
# Epoch 12/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5417 - accuracy: 0.7355
# Epoch 13/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5416 - accuracy: 0.7357
# Epoch 14/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5410 - accuracy: 0.7348
# Epoch 15/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5406 - accuracy: 0.7349
# Epoch 16/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5409 - accuracy: 0.7355
# Epoch 17/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5402 - accuracy: 0.7361
# Epoch 18/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5393 - accuracy: 0.7362
# Epoch 19/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5395 - accuracy: 0.7365
# Epoch 20/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5387 - accuracy: 0.7367
# Epoch 21/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5394 - accuracy: 0.7369
# Epoch 22/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5388 - accuracy: 0.7376
# Epoch 23/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5384 - accuracy: 0.7371
# Epoch 24/200
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5382 - accuracy: 0.7372
# Epoch 25/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5379 - accuracy: 0.7390
# Epoch 26/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5380 - accuracy: 0.7376
# Epoch 27/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5378 - accuracy: 0.7372
# Epoch 28/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5377 - accuracy: 0.7366
# Epoch 29/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5376 - accuracy: 0.7378
# Epoch 30/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5372 - accuracy: 0.7386
# Epoch 31/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5366 - accuracy: 0.7385
# Epoch 32/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.
200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5308 - accuracy: 0.7409
# Epoch 91/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5310 - accuracy: 0.7398
# Epoch 92/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5309 - accuracy: 0.7398
# Epoch 93/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5305 - accuracy: 0.7405
# Epoch 94/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5305 - accuracy: 0.7403
# Epoch 95/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5309 - accuracy: 0.7395
# Epoch 96/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5312 - accuracy: 0.7403
# Epoch 97/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5309 - accuracy: 0.7387
# Epoch 98/200
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5305 - accuracy: 0.7393
# Epoch 99/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5308 - accuracy: 0.7403
# Epoch 100/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5304 - accuracy: 0.7405
# Epoch 101/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5304 - accuracy: 0.7405
# Epoch 102/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5301 - accuracy: 0.7405
# Epoch 103/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5308 - accuracy: 0.7405
# Epoch 104/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5307 - accuracy: 0.7406
# Epoch 105/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5305 - accuracy: 0.7407
# Epoch 106/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5298 - accuracy: 0.7409
# Epoch 107/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5305 - accuracy: 0.7390
# Epoch 108/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5302 - accuracy: 0.7402
# Epoch 109/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5303 - accuracy: 0.7404
# Epoch 110/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5312 - accuracy: 0.7397
# Epoch 111/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5300 - accuracy: 0.7405
# Epoch 112/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5295 - accuracy: 0.7408
# Epoch 113/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5302 - accuracy: 0.7402
# Epoch 114/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5298 - accuracy: 0.7407
# Epoch 115/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5303 - accuracy: 0.7398
# Epoch 116/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5300 - accuracy: 0.7411
# Epoch 117/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5298 - accuracy: 0.7403
# Epoch 118/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5302 - accuracy: 0.7399
# Epoch 119/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5294 - accuracy: 0.7402
# Epoch 120/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5293 - accuracy: 0.7400
# Epoch 121/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5307 - accuracy: 0.7409
# Epoch 122/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5293 - accuracy: 0.7408
# Epoch 123/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5297 - accuracy: 0.7400
# Epoch 124/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5297 - accuracy: 0.7398
# Epoch 125/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5293 - accuracy: 0.7413
# Epoch 126/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5300 - accuracy: 0.7397
# Epoch 127/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5298 - accuracy: 0.7411
# Epoch 128/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5298 - accuracy: 0.7409
# Epoch 129/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5294 - accuracy: 0.7404
# Epoch 130/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5292 - accuracy: 0.7414
# Epoch 131/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5295 - accuracy: 0.7411
# Epoch 132/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5293 - accuracy: 0.7410
# Epoch 133/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5300 - accuracy: 0.7409
# Epoch 134/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5299 - accuracy: 0.7409
# Epoch 135/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5298 - accuracy: 0.7412
# Epoch 136/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5287 - accuracy: 0.7415
# Epoch 137/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5294 - accuracy: 0.7407
# Epoch 138/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5291 - accuracy: 0.7418
# Epoch 139/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5290 - accuracy: 0.7404
# Epoch 140/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5288 - accuracy: 0.7416
# Epoch 141/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5290 - accuracy: 0.7420
# Epoch 142/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5289 - accuracy: 0.7416
# Epoch 143/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5296 - accuracy: 0.7407
# Epoch 144/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5294 - accuracy: 0.7416
# Epoch 145/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5294 - accuracy: 0.7400
# Epoch 146/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5301 - accuracy: 0.7409
# Epoch 147/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5301 - accuracy: 0.7408
# Epoch 148/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5299 - accuracy: 0.7406
# Epoch 149/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5294 - accuracy: 0.7414
# Epoch 150/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5289 - accuracy: 0.7408
# Epoch 151/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5301 - accuracy: 0.7411
# Epoch 152/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5298 - accuracy: 0.7407
# Epoch 153/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5289 - accuracy: 0.7411
# Epoch 154/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5283 - accuracy: 0.7418
# Epoch 155/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5291 - accuracy: 0.7413
# Epoch 156/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5290 - accuracy: 0.7399
# Epoch 157/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5293 - accuracy: 0.7398
# Epoch 158/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5289 - accuracy: 0.7420
# Epoch 159/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5286 - accuracy: 0.7418
# Epoch 160/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5294 - accuracy: 0.7406
# Epoch 161/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5290 - accuracy: 0.7402
# Epoch 162/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5284 - accuracy: 0.7416
# Epoch 163/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5286 - accuracy: 0.7409
# Epoch 164/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5291 - accuracy: 0.7395
# Epoch 165/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5285 - accuracy: 0.7405
# Epoch 166/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5287 - accuracy: 0.7401
# Epoch 167/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5288 - accuracy: 0.7407
# Epoch 168/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5287 - accuracy: 0.7416
# Epoch 169/200
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5293 - accuracy: 0.7412
# Epoch 170/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5288 - accuracy: 0.7416
# Epoch 171/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5278 - accuracy: 0.7414
# Epoch 172/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5304 - accuracy: 0.7407
# Epoch 173/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5292 - accuracy: 0.7397
# Epoch 174/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5286 - accuracy: 0.7413
# Epoch 175/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5288 - accuracy: 0.7402
# Epoch 176/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5287 - accuracy: 0.7404
# Epoch 177/200
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5286 - accuracy: 0.7412
# Epoch 178/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5298 - accuracy: 0.7404
# Epoch 179/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5286 - accuracy: 0.7406
# Epoch 180/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5281 - accuracy: 0.7410
# Epoch 181/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5282 - accuracy: 0.7409
# Epoch 182/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5283 - accuracy: 0.7401
# Epoch 183/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5285 - accuracy: 0.7402
# Epoch 184/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5290 - accuracy: 0.7393
# Epoch 185/200
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5283 - accuracy: 0.7399
# Epoch 186/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5282 - accuracy: 0.7397
# Epoch 187/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5284 - accuracy: 0.7403
# Epoch 188/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5288 - accuracy: 0.7403
# Epoch 189/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5280 - accuracy: 0.7410
# Epoch 190/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5286 - accuracy: 0.7420
# Epoch 191/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5285 - accuracy: 0.7409
# Epoch 192/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5277 - accuracy: 0.7419
# Epoch 193/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5286 - accuracy: 0.7405
# Epoch 194/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5281 - accuracy: 0.7402
# Epoch 195/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5284 - accuracy: 0.7411
# Epoch 196/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5281 - accuracy: 0.7414
# Epoch 197/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5283 - accuracy: 0.7406
# Epoch 198/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5279 - accuracy: 0.7408
# Epoch 199/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5284 - accuracy: 0.7407
# Epoch 200/200
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5280 - accuracy: 0.7418

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5934 - accuracy: 0.7291 - 960ms/epoch - 4ms/step
# Loss: 0.5934334397315979, Accuracy: 0.7290962338447571

# %%
# Save the model
nn.save("charity_learning_v3.h5")
